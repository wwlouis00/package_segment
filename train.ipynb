# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo mode=checks
# Out:
# WARNING ⚠️ 'yolo mode=checks' is deprecated. Use 'yolo checks' instead.
# Ultralytics YOLOv8.0.120 🚀 Python-3.9.16 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 7974MiB)
# Setup complete ✅ (20 CPUs, 31.1 GB RAM, 609.0/1828.9 GB disk)

# %%
# from roboflow import Roboflow
# rf = Roboflow(api_key="AtgKbLMmJOglsXJRqoA6")
# project = rf.workspace("louis-pwwfg").project("factory_package")
# dataset = project.version(2).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.134 is required but found version=8.0.120, to fix: `pip install ultralytics==8.0.134`
#
# Version export complete for yolov8 format
# ...
# Extracting Dataset Version Zip to factory_package-2 in yolov8:: 100%|██████████| 2054/2054 [00:00<00:00, 21613.67it/s]

# %%
# print(dataset.location)
# Out:
# /home/wwlouis/project/yolov8/factory_package-1

# %%
# !yolo task=segment mode=train model=model/yolov8n-seg.pt data=/home/wwlouis/project/yolov8/factory_package-2/data.yaml epochs=20 imgsz=640
# Out:
# New https://pypi.org/project/ultralytics/8.0.227 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.120 🚀 Python-3.9.16 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 7974MiB)
# ...

# %%
Image(filename=f'/home/wwlouis/.pyenv/runs/segment/train15/confusion_matrix.png', width=900)

# %%
Image(filename=f'/home/wwlouis/.pyenv/runs/segment/train7/results.png', width=900)

# %%
Image(filename=f'/home/wwlouis/.pyenv/runs/segment/train7/val_batch0_pred.jpg', height=600)

# %%
Image(filename=f'/home/wwlouis/.pyenv/runs/segment/train7/val_batch1_pred.jpg', height=600)
